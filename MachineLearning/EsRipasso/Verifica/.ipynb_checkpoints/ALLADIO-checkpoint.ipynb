# %% [markdown]
# # Verifica
# ## Esercizio 1A-B

# %%
import numpy as np
nDati = 1000
nErrori = 20

dati = np.random.normal(19,5,nDati)
dati[np.random.choice(np.arange(nDati), size = nErrori, replace = False)] = 9999.9 #inserimento degli errori in maniera casuale
#print(dati)


mat = np.array([dati[i:5+i] for i in range(len(dati)-4)]) #raggruppamento dei valori vicini a gruppi di 5
print('\n',mat)

erroriRavvicinati = np.sum(mat == 9999.9, axis=1) #restituisce per ogni riga della matrice la somma di valori = 9999.9 in quella riga

for errore in erroriRavvicinati:
    if errore >= 2: #se il numero di errori in una riga è >= 2 si segnala il problema
        print('\nCentralina in riparazione')
        break

newArray = np.delete(dati, np.argwhere(dati == 9999.9)) #creazione del nuovo array senza errori
print(f"\nNuovo array senza errori:\n{newArray}")
print(f"\nMedia dell'array senza errori: {newArray.mean()}")
print(f"Valore massimo dell'array senza errori: {newArray.max()}")
print(f"Valore minimo dell'array senza errori: {newArray.min()}")



print('\n\n------------------------------1B---------------------------\n\n')

nDati = 60*24

#calcolo del numero di errori per le due centraline
nErrori2 = round((nDati*2) / 100)
nErrori3 = round(nDati/100)

#creazione centraline e inserimento errori
centralina1 = np.random.normal(19,5,nDati)
centralina1[np.random.choice(np.arange(nDati), size = nErrori, replace = False)] = 9999.9
centralina2 = np.random.normal(19,5,nDati)
centralina2[np.random.choice(np.arange(nDati), size = nErrori2, replace = False)] = 9999.9
centralina3 = np.random.normal(19,5,nDati)
centralina3[np.random.choice(np.arange(nDati), size = nErrori3, replace = False)] = 9999.9

#print(centralina1)
#print(centralina2)
#print(centralina3)

mat = np.array([centralina1,centralina2,centralina3]).transpose() #creazione di una matrice con il transpose per associare i dati in modo corretto
print(mat)



#Eliminazione (NON FUNZIONA)
coord = np.argwhere(mat == 9999.9) #coordinate della matrice in cui ci sono errori
coord = coord[:,1] #si calcola solo il numero delle righe
print(coord)

newMat = np.delete(mat, coord, axis=1)
print(newMat)


#controllo righe che hanno tutti e tre errori
for riga in mat:
    if np.all(riga) == 9999.9: #np.all() per controllare che la condizione valga per tutti e tre i dati
        print('Tutte e 3 le centraline hanno un errore nello stesso minuto')
        break

#newMat = np.delete(mat, np.argwhere(mat[0] == 9999.9))
#print(newMat)
# Out:
#  [[2.75862300e+01 2.90430043e+01 1.78917868e+01 2.63403325e+01
#   1.88553970e+01]
#  [2.90430043e+01 1.78917868e+01 2.63403325e+01 1.88553970e+01
#   1.47935736e+01]
#  [1.78917868e+01 2.63403325e+01 1.88553970e+01 1.47935736e+01
#   9.90656098e+00]
#  ...
#  [1.29391479e+01 1.04752946e+01 1.36752013e+01 2.20315841e+01
#   2.09691602e+01]
#  [1.04752946e+01 1.36752013e+01 2.20315841e+01 2.09691602e+01
#   2.84778616e+01]
#  [1.36752013e+01 2.20315841e+01 2.09691602e+01 2.84778616e+01
#   9.99990000e+03]]
#
# Centralina in riparazione
#  19.22865924 16.30221474 13.87972305 20.41993788 28.39517997 18.79977374
#  30.2683478  21.16860155 13.22324311 14.08790823 21.81589044 16.50658666
#  15.80646417 29.31015828 13.14412866 13.63630243 17.60329004 22.92733832
#  22.95945224 13.47491251 13.12933313 18.61585109 18.42361639 22.7182367
#  13.9531108  21.05878663  6.34907943 21.06724322 16.05072263 24.85441895
#  18.41606906 17.11531259 21.64784284 21.05154102 21.02319128 23.74600979
#  30.65436311 21.82581499 27.33172377 15.30887102 16.0135774  18.20045713
#  26.66041111  6.65422255 14.83899275 23.11114783 20.6408704  12.99728884
#  20.55585492 26.87502221 12.93914787 10.47529458 13.6752013  22.03158407
#  20.9691602  28.47786157]
#
# Media dell'array senza errori: 19.251565444183683
# Valore massimo dell'array senza errori: 34.802023055313086
# Valore minimo dell'array senza errori: 2.4792709038893292
#
#
# ------------------------------1B---------------------------
#
#
# [[26.0609061  14.32861018 28.04594189]
#  [15.62991001 16.76765474 20.0652803 ]
#  [18.67938478 18.79461734 12.25434701]
#  ...
#  [21.31782645 14.33565744 17.20090281]
#  [24.09304902 23.80483426 22.18478134]
#  [19.22319492 23.61849763 18.29210099]]
# [2 2 1 1 0 1 1 1 2 0 1 0 0 0 2 2 1 1 2 1 0 0 2 1 1 2 1 1 2 0 0 1 2 0 0 1 1
#  2 1 1 2 1 0 0 1 1 0 1 1 0 2 1 2 1 1 1 0 0 1 1 0 0 0]
# []

# %% [markdown]
# ## Esercizio 2

# %%
import numpy as np

nGiorni = 5
puntoPartenza = 0

movimenti = np.random.choice([1,-1], size=3600*24*nGiorni) #scelta del movimento per ogni secondo tra due scelte
#print(movimenti)
print(f'Spostamento totale: {puntoPartenza + movimenti.sum()}cm') #calcolo dello spostamento
# Out:
# Spostamento totale: -362cm

# %% [markdown]
# ## Esercizio 3

# %%
import numpy as np

nPoligoni = 10

coordinate = np.random.randint(-100,100, size=8*nPoligoni).reshape(-1,4,2) #4 coordinate a gruppi di 2 per ogni poligono
print(coordinate)
# Out:
# [[[ -18  -44]
#   [ -49   69]
#   [   0  -79]
#   [  78    1]]
#
#  [[ -99   95]
#   [  74   19]
#   [   0  -94]
#   [  98   40]]
#
#  [[  54  -82]
#   [  68  -15]
#   [-100  -41]
#   [ -56   35]]
#
#  [[   0  -83]
#   [  89  -15]
#   [  76  -19]
#   [ -87  -24]]
#
#  [[  37  -64]
#   [  13  -88]
#   [ -10   83]
#   [ -43  -22]]
#
#  [[  55   70]
#   [  76   22]
#   [  33   23]
#   [ -18   27]]
#
#  [[  53  -72]
#   [ -95  -72]
#   [ -56    7]
#   [  68    9]]
#
#  [[ -45   12]
#   [  42  -93]
#   [ -46  -31]
#   [  52   -7]]
#
#  [[  42   29]
#   [-100  -12]
#   [  19   59]
#   [  85  -92]]
#
#  [[  28  -59]
#   [ -73  -20]
#   [ -28  -95]
#   [  15  -53]]]
