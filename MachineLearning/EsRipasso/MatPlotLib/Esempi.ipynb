# %% [markdown]
# # Serie di grafici

# %%
from matplotlib import pyplot
import matplotlib.pyplot as pl

x = pl.plot([1,2,3,6,4,2,3,4])
pl.show(x)

# %%
x = [3.3,4.4,4.5,6.5]
y = [3.,5.,6.,7.]
pl.plot(x,y)
pl.show()

# %%
fig, ax = pl.subplots()
ax.plot(x, y, label = 'Funzione 1')
ax.set_xlabel('Ascissa')
ax.set_ylabel('Ordinata')
ax.set_title('Secondo grafico')
ax.legend()
pl.show()

# %%
import numpy as np 
x = np.linspace(0.,10.,50)
y = np.sin(x)
pl.plot(x,y)
pl.show()

# %%
x = np.linspace(0.,10.,50)
y = np.sin(x)
pl.plot(x,y, linestyle='--')
pl.show()

# %%
x = np.linspace(0.,10.,50)
y = np.sin(x)
pl.plot(x,y, linewidth=10)
pl.show()

# %%
x = np.linspace(0.,10.,50)
y = np.sin(x)
pl.plot(x,y, marker='o')
pl.show()

# %%
x = np.linspace(0.,10.,50)
y = np.sin(x)
pl.plot(x,y, marker='o', markersize=10)
pl.show()

# %%
x = np.linspace(0.,10.,50)
y = np.sin(x)
pl.plot(x,y, color='red')
pl.show()

# %%
x = np.linspace(0.,10.,50)
y = np.sin(x)
pl.plot(x,y, 'go-') #stringa contenente opzioni di spessore, marker e colore
pl.show()

# %%
x = np.linspace(0.,10.,50)
y = np.sin(x)
pl.plot(x,y, marker='*', linestyle='') #stringa contenente opzioni di spessore, marker e colore
pl.show()

# %%
x = np.linspace(0.,10.,50)
y = np.sin(x)
pl.plot(x,y, label='sin(x)')
pl.legend()
pl.show()

# %%
x = np.linspace(0.,10.,50)
y = np.sin(x)
pl.plot(x,y, label='sin(x)')
pl.legend(loc='best') #locazione della stringa
pl.show()

# %%
x = np.linspace(0.,10.,50)
y = np.sin(x)
pl.plot(x,y)
pl.title('Sin(x)')
pl.show()

# %%
x = np.linspace(0.,10.,50)
y = np.sin(x)
pl.plot(x,y)
pl.grid(True)
pl.show()

# %%
x = np.linspace(0.,10.,50)
y = np.sin(x)
pl.plot(x,y)
pl.xlabel('x axis')
pl.ylabel('y axis')
pl.show()

# %%
x = np.linspace(0.,10.,50)
y = np.sin(x)
pl.plot(x,y)
pl.xlim(0,1)
pl.ylim(-1,1)
pl.show()

# %%
x = np.linspace(0.,10.,50)
y = np.sin(x)
z = np.cos(x)
pl.plot(x,y, label='sin(x)', color='b')
pl.plot(x,z, label='cos(x)', color='r')
pl.legend(loc='best')
pl.show()

# %%
x = np.random.uniform(-10,10, size=50)
y = np.random.uniform(-10,10, size=50)
colors = np.random.uniform(0,1, size=(50,3))
dims = np.random.uniform(50,150, size=50)

# %%
fig, ax = pl.subplots(figsize=(8,8))
ax.scatter(x,y, c=colors, s=dims, marker='v')
ax.set_xlabel('x', fontsize=20)
ax.set_ylabel('y', fontsize=20)
ax.tick_params(axis='both', labelsize=16)
ax.grid(True)
pl.show()

# %% [markdown]
# # Istogramma

# %%
import numpy as np

dado1=np.random.randint(1,7,50000)
dado2=np.random.randint(1,7,50000)
somma=dado1+dado2

# %%
from matplotlib import pyplot
import matplotlib.pyplot as pl

fig,ax = pl.subplots(figsize=(8,8))
ax.hist(somma,bins=11)
ax.set_xlabel("somma",fontsize=16)
ax.set_ylabel("frequenza assoluta", fontsize=16)
ax.tick_params(axis="x", labelsize=16)
ax.tick_params(axis="x", labelsize=16)
ax.set_title("La distribuzione della somma delle uscite di due dadi a 6 facce", fontsize=20)

pl.show()

# %% [markdown]
# # Pixel pseudocasuali

# %%
mat = np.random.uniform(0.0,1.0, size=(100,100,3))
fig,ax = pl.subplots(figsize=(8,8))
ax.imshow(mat)
ax.set_title('Pixel pseudocasuali', fontsize=20)
ax.axis('off')
pl.show()

# %%
mat = np.random.uniform(0.0,1.0, size=(100,100))
fig,ax = pl.subplots(figsize=(8,8))
ax.imshow(mat)
ax.set_title('Pixel pseudocasuali', fontsize=20)
ax.axis('off')
pl.show()

# %%
mat = np.random.uniform(0.0,1.0, size=(100,100))
fig,ax = pl.subplots(figsize=(8,8))
ax.imshow(mat, cmap='Greys')
ax.set_title('Pixel pseudocasuali', fontsize=20)
ax.axis('off')
pl.show()

# %%
import numpy as np
from matplotlib import pyplot
import matplotlib.pyplot as pl

mat = np.linspace(0,1,num=100)
#mat.shape=(1,100)
fig,ax = pl.subplots(figsize=(8,8))
mat = np.stack((mat,mat,mat), axis=0) #per farla più spessa
ax.imshow(mat, cmap='Blues')
ax.set_title('Gradazioni di Blu', fontsize=20)
ax.axis('off')
pl.show()

# %% [markdown]
# # Sottografici

# %%
import numpy as np
from matplotlib import pyplot
import matplotlib.pyplot as pl

fig,axs = pl.subplots(nrows=3,ncols=1, figsize=(10,8))
pl.show()

# %%
x = np.linspace(0,10,500)
F1 = np.sin(x)
F2 = np.exp(-x)
R = np.random.uniform(-1,1, size=500)

# %%
fig,axs=pl.subplots(nrows=3, ncols=1, figsize=(10,8))

axs[0].plot(x, F1, color='red', linestyle='-.', 
            linewidth=5, label='sin(x)')
axs[1].plot(x, F2, color=(0.0,1.0,0.0), linestyle='-', linewidth=10, label='exp(-x)')
axs[2].plot(x, R, color=(0.0,0.0,1.0,0.4), marker = '.', linestyle='', label='random')
#axs[0].set_xlabel('ascissa',fontsize=20) #non si vede
axs[0].set_ylabel('ordinata',fontsize=20)
axs[0].tick_params(axis='x', labelsize=20)
axs[0].tick_params(axis='y', labelsize=20)
axs[0].legend(fontsize=16)
#axs[1].set_xlabel('ascissa',fontsize=20) #non si vede
axs[1].set_ylabel('ordinata',fontsize=20)
axs[1].tick_params(axis='x', labelsize=20)
axs[1].tick_params(axis='y', labelsize=20)
axs[1].legend(fontsize=16)
axs[2].set_xlabel('ascissa',fontsize=20)
axs[2].set_ylabel('ordinata',fontsize=20)
axs[2].tick_params(axis='x', labelsize=20)
axs[2].tick_params(axis='y', labelsize=20)
axs[2].legend(fontsize=16)
fig.suptitle("Tre grafici all'interno di una sola figura", fontsize=25)
pl.show()
